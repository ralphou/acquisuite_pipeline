# %%
import numpy as np
import pandas as pd

# %%
csv_list = []
for i in np.arange(0, 1):
    x = str(i).zfill(3)
    #csv_list = np.append(csv_list, pd.read_csv("updateModhopper_csv_files/Obvius_backlog_data_" + x + ".csv"))
# Out:
# ['Meter name' '33 Gas' '34-CT-1 Makeup' ... nan nan nan]

# %%
pd.read_csv("updateModhopper_csv_files/Obvius_backlog_data_" + x + ".csv")
# Out:
#                Facility                            Building 33  \
# 0            Meter name                                 33 Gas
# 1              Meter id  lbnl_building33_gas_submeter_gas12700
# 2             Timestamp             Building 33 - 33 Gas (raw)
# 3      2015-03-19 13:25                                    NaN
# 4      2015-03-19 13:30                                    NaN
# 5      2015-03-19 13:35                                    NaN
# 6      2015-03-19 13:40                                    NaN
# 7      2015-03-19 13:45                                    NaN
# 8      2015-03-19 13:50                                    NaN
# 9      2015-03-19 13:55                                    NaN
# 10     2015-03-19 14:00                                    NaN
# 11     2015-03-19 14:05                                    NaN
# 12     2015-03-19 14:10                                    NaN
# 13     2015-03-19 14:15                                    NaN
# ...

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
